# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'originated', 'term', 'of', 'as']

# %%
s = 'hello world'
t = collections.deque(maxlen = 3)
t.append(s[0])
t.append(s[1])
t.append(s[2])
t.append(s[3])
print(t[0])
print(t[1])
# Out:
# e
# l

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.007938
# Nearest to were: renoir, millennia, naia, miscarriage, vauban, marcus, personalities, dry,
# Nearest to however: caroli, killings, terminator, ned, weinberg, nimitz, lanier, impossibility,
# Nearest to who: acapulco, postulate, science, garbage, practises, jarvis, binitarianism, ung,
# Nearest to eight: annapolis, converged, lien, buyers, mep, hats, creates, fastest,
# Nearest to and: indentations, ts, meticulously, multipurpose, strings, sparky, estonians, clarkson,
# Nearest to about: stranger, proportionately, expedient, aes, tunings, jfif, ata, gamal,
# Nearest to this: tigre, fourier, conductive, dek, dorian, sig, nomination, dcs,
# Nearest to world: corollary, preposition, stricter, tero, mercy, kgf, immediately, paleontologist,
# Nearest to other: summa, figuratively, tedious, tsuba, eternally, exaggeration, careless, komodoensis,
# Nearest to all: gaslight, shores, sparking, worsening, counteract, stacy, unending, contingency,
# Nearest to during: cologne, freelance, repression, bradman, skaro, misgivings, failure, northamptonshire,
# Nearest to had: tei, petersburg, oriole, northamptonshire, interactions, scathing, proust, switching,
# Nearest to as: accumulated, chernobyl, kee, rushdie, volvo, dmd, clearest, mahommed,
# Nearest to up: supply, vichy, passive, creditors, cassiodorus, shenzhen, buns, smoothing,
# Nearest to states: embryogenesis, aau, isdn, biya, flare, fremont, nauru, randolph,
# Nearest to called: virginity, knobs, halicarnassus, incentives, situation, prescribe, fetish, seminaries,
# Average loss at step 2000: 4.356455
# Average loss at step 4000: 3.877286
# Average loss at step 6000: 3.787833
# Average loss at step 8000: 3.685640
# Average loss at step 10000: 3.609456
# Nearest to were: are, was, kumasi, wenham, have, dry, sensation, pertains,
# Nearest to however: where, maria, but, postgresql, mahjong, subculture, has, when,
# Nearest to who: which, he, and, she, functionally, postulate, leonhard, they,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to and: or, who, s, aboriginals, aidan, inconspicuous, bore, american,
# Nearest to about: stranger, tunings, defense, aes, proportionately, variant, lebeau, stove,
# Nearest to this: it, the, a, which, ostia, childbearing, tweed, eleazar,
# Nearest to world: mercy, stricter, paleontologist, brigham, garbled, immediately, corrupt, overcame,
# Nearest to other: figuratively, idleness, kombat, merleau, tedious, related, most, vilayet,
# Nearest to all: productivity, silos, biruni, kalmar, accord, tfl, murron, toronto,
# Nearest to during: by, pancake, ncaa, weierstrass, united, when, purchaser, within,
# Nearest to had: has, was, have, into, been, bridging, practicality, sexual,
# Nearest to as: beasts, by, news, elca, cometary, cree, ferraris, mediawiki,
# Nearest to up: supply, vichy, cape, melody, importation, cassiodorus, collecting, passive,
# Nearest to states: embryogenesis, wilton, married, nauru, grimoire, usmc, condoned, words,
# Nearest to called: virginity, tok, situation, mouthwash, kk, unpopularity, rabbit, halicarnassus,
# Average loss at step 12000: 3.601095
# Average loss at step 14000: 3.568009
# Average loss at step 16000: 3.411864
# Average loss at step 18000: 3.454921
# Average loss at step 20000: 3.538854
# Nearest to were: are, was, had, have, by, be, been, is,
# Nearest to however: but, where, when, that, and, subculture, blanco, while,
# Nearest to who: which, he, she, they, often, also, burdened, storehouses,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to and: or, but, including, however, which, with, among, in,
# Nearest to about: proportionately, weinstein, nameless, lebeau, stranger, defense, aes, aliens,
# Nearest to this: which, it, the, definite, metaphorical, a, tweed, its,
# Nearest to world: stricter, mercy, brigham, immediately, smoothness, garbled, paleontologist, corollary,
# Nearest to other: many, idleness, various, are, related, such, these, some,
# Nearest to all: some, many, those, any, most, ideas, especial, questionable,
# Nearest to during: pancake, by, within, ncaa, when, from, united, at,
# Nearest to had: has, have, was, were, already, been, took, when,
# Nearest to as: single, for, elca, encoding, specific, after, mammalia, victors,
# Nearest to up: them, melody, supply, chicanos, out, collecting, ecstatic, bubbled,
# Nearest to states: embryogenesis, kingdom, nauru, wilton, grimoire, words, ateneo, married,
# Nearest to called: virginity, exposure, tok, named, kk, unpopularity, lasor, fouls,
# Average loss at step 22000: 3.500247
# Average loss at step 24000: 3.489459
# Average loss at step 26000: 3.481438
# Average loss at step 28000: 3.479988
# Average loss at step 30000: 3.501498
# Nearest to were: are, was, have, had, been, ame, szabo, intriguing,
# Nearest to however: but, when, where, while, believes, although, and, that,
# Nearest to who: he, which, they, she, never, and, also, often,
# Nearest to eight: nine, seven, five, four, six, three, zero, two,
# Nearest to and: or, but, including, among, in, ruptured, like, however,
# Nearest to about: on, furious, weinstein, postpone, wreath, around, ugandan, lebeau,
# Nearest to this: which, it, that, what, there, ostia, definite, another,
# Nearest to world: stricter, mercy, sovereign, smoothness, mujibur, branches, deployable, paleontologist,
# Nearest to other: various, idleness, related, these, many, some, different, principal,
# Nearest to all: some, many, these, any, those, images, ideas, questionable,
# Nearest to during: in, when, after, from, within, pancake, ncaa, through,
# Nearest to had: has, have, was, were, gave, when, already, been,
# Nearest to as: elca, beasts, by, sushi, coincide, globalisation, gallus, disbanded,
# Nearest to up: them, him, off, out, melody, chicanos, collecting, ecstatic,
# Nearest to states: kingdom, embryogenesis, nauru, ateneo, wilton, grimoire, words, location,
# Nearest to called: virginity, named, used, superhuman, unpopularity, duesberg, situation, kk,
# Average loss at step 32000: 3.500256
# Average loss at step 34000: 3.495619
# Average loss at step 36000: 3.452323
# Average loss at step 38000: 3.297808
# Average loss at step 40000: 3.427209
# Nearest to were: are, have, was, had, been, be, although, reproducible,
# Nearest to however: but, when, though, while, where, that, would, although,
# Nearest to who: which, he, she, often, that, they, dirichlet, usually,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to and: or, like, but, obedient, including, while, in, b,
# Nearest to about: over, weinstein, on, furious, wreath, proportionately, lebeau, postpone,
# Nearest to this: which, it, that, the, definite, liu, senatorial, another,
# Nearest to world: sovereign, brigham, immediately, skies, smoothness, u, fastest, deployable,
# Nearest to other: various, different, hathaway, principal, many, such, related, some,
# Nearest to all: these, both, any, many, hogg, ideas, toronto, various,
# Nearest to during: after, when, throughout, against, ncaa, before, within, in,
# Nearest to had: has, have, was, were, already, supplant, yellowstone, gluon,
# Nearest to as: beasts, bioleaching, by, knife, inferiority, specific, arrayed, futurists,
# Nearest to up: them, out, him, off, melody, collecting, chicanos, ecstatic,
# Nearest to states: kingdom, ateneo, nauru, embryogenesis, nations, kal, protestantism, beds,
# Nearest to called: named, virginity, kk, lasor, superhuman, austerlitz, used, see,
# Average loss at step 42000: 3.435898
# Average loss at step 44000: 3.451367
# Average loss at step 46000: 3.446476
# Average loss at step 48000: 3.359369
# Average loss at step 50000: 3.381112
# Nearest to were: are, have, was, had, be, those, been, including,
# Nearest to however: but, although, though, while, when, that, where, and,
# Nearest to who: he, she, which, they, there, also, often, never,
# Nearest to eight: six, seven, nine, four, five, three, two, one,
# Nearest to and: or, but, while, including, however, sparky, of, like,
# Nearest to about: over, weinstein, anode, furious, around, iaea, conquistador, postpone,
# Nearest to this: which, it, that, he, the, another, definite, some,
# Nearest to world: sovereign, deployable, fastest, brigham, nipples, carbine, u, galvanized,
# Nearest to other: various, different, faust, older, many, caesura, related, tedious,
# Nearest to all: any, both, these, some, because, silos, those, various,
# Nearest to during: after, in, at, when, against, through, within, throughout,
# Nearest to had: has, have, was, were, supplant, having, already, yellowstone,
# Nearest to as: gallus, millionth, cometary, arrayed, bioleaching, ferraris, thinning, coincide,
# Nearest to up: out, them, off, him, collecting, melody, ecstatic, back,
# Nearest to states: kingdom, nations, ateneo, nauru, embryogenesis, beds, ohrid, protestantism,
# Nearest to called: named, austerlitz, virginity, known, superhuman, see, unpopularity, kk,
# Average loss at step 52000: 3.432161
# Average loss at step 54000: 3.425230
# Average loss at step 56000: 3.441083
# Average loss at step 58000: 3.398308
# Average loss at step 60000: 3.392841
# Nearest to were: are, was, have, had, including, been, although, be,
# Nearest to however: but, although, though, when, that, which, while, where,
# Nearest to who: she, he, still, never, which, now, that, activex,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to and: or, but, wgn, while, giancana, including, sparky, although,
# Nearest to about: over, around, weinstein, iaea, stove, bsa, anode, postpone,
# Nearest to this: it, which, there, that, some, the, liu, cpm,
# Nearest to world: sovereign, deployable, european, catastrophe, nipples, country, outsold, flashing,
# Nearest to other: various, different, many, more, faust, principal, older, eamonn,
# Nearest to all: some, any, those, various, many, both, these, every,
# Nearest to during: after, before, at, when, in, throughout, within, rejoicing,
# Nearest to had: has, have, was, were, supplant, having, gave, malevich,
# Nearest to as: thirteenth, ferraris, dangerously, dostoyevsky, coincide, beasts, in, lichfield,
# Nearest to up: out, them, off, him, together, back, chicanos, coincidental,
# Nearest to states: kingdom, nations, nauru, ateneo, countries, embryogenesis, categories, latino,
# Nearest to called: named, used, known, considered, kk, austerlitz, notation, quantifying,
# Average loss at step 62000: 3.237809
# Average loss at step 64000: 3.259877
# Average loss at step 66000: 3.399326
# Average loss at step 68000: 3.393958
# Average loss at step 70000: 3.353604
# Nearest to were: are, was, have, be, had, including, although, reproducible,
# Nearest to however: but, although, though, where, that, while, when, which,
# Nearest to who: she, he, never, which, dirichlet, still, born, often,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to and: or, while, like, but, including, clich, flu, see,
# Nearest to about: over, around, iaea, weinstein, on, causing, confer, postpone,
# Nearest to this: which, it, the, there, that, some, usually, cimmerians,
# Nearest to world: deployable, sovereign, country, catastrophe, supersonic, flashing, koenig, abeokuta,
# Nearest to other: different, various, many, some, older, traditional, western, potash,
# Nearest to all: some, many, any, every, various, several, because, these,
# Nearest to during: after, before, throughout, within, in, through, rejoicing, at,
# Nearest to had: has, have, was, were, wanted, having, supplant, since,
# Nearest to as: ferraris, coincide, beasts, cometary, before, mckellen, elca, daniels,
# Nearest to up: out, off, them, back, him, eye, down, ecstatic,
# Nearest to states: kingdom, nations, nauru, ateneo, countries, phone, us, postman,
# Nearest to called: named, referred, used, known, menstruation, see, austerlitz, preeminent,
# Average loss at step 72000: 3.375681
# Average loss at step 74000: 3.347512
# Average loss at step 76000: 3.311559
# Average loss at step 78000: 3.352400
# Average loss at step 80000: 3.379254
# Nearest to were: are, had, was, have, been, be, those, although,
# Nearest to however: but, although, though, that, where, while, when, which,
# Nearest to who: she, he, never, they, which, usually, often, born,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to and: or, while, but, including, soldiery, charlize, scholastic, tricked,
# Nearest to about: over, postpone, around, iaea, weinstein, dimensional, furious, cyrenaica,
# Nearest to this: which, it, the, there, usc, what, he, another,
# Nearest to world: catastrophe, deployable, country, sovereign, koenig, goldoni, discontinuing, supersonic,
# Nearest to other: various, mainstream, western, different, older, sentient, principal, intrusive,
# Nearest to all: any, every, many, several, both, various, some, these,
# Nearest to during: after, before, throughout, in, despite, when, while, within,
# Nearest to had: have, has, was, were, wanted, malevich, began, having,
# Nearest to as: millionth, arrayed, rang, anglicized, neutral, beasts, heyerdahl, hackney,
# Nearest to up: out, off, them, him, back, down, together, taraki,
# Nearest to states: kingdom, nations, us, nauru, ateneo, postman, countries, state,
# Nearest to called: named, used, austerlitz, known, referred, considered, menstruation, siwa,
# Average loss at step 82000: 3.407981
# Average loss at step 84000: 3.410179
# Average loss at step 86000: 3.386706
# Average loss at step 88000: 3.348091
# Average loss at step 90000: 3.365563
# Nearest to were: are, had, was, have, while, although, consequently, ferries,
# Nearest to however: but, although, though, that, while, since, where, stationary,
# Nearest to who: he, she, which, never, also, often, still, dirichlet,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to and: or, but, while, including, of, nor, in, burr,
# Nearest to about: over, around, iaea, postpone, weinstein, wreath, collectivity, concerning,
# Nearest to this: which, it, some, the, modules, another, venetia, marcel,
# Nearest to world: deployable, galvanized, country, koenig, catastrophe, skies, iconic, spare,
# Nearest to other: various, western, mediated, different, older, sentient, mainstream, handloading,
# Nearest to all: several, any, many, every, various, some, both, those,
# Nearest to during: after, before, at, while, in, throughout, despite, when,
# Nearest to had: has, have, was, were, having, malevich, wanted, already,
# Nearest to as: arrayed, bioleaching, became, cometary, daniels, subduing, gmt, werewolf,
# Nearest to up: out, off, them, down, back, him, together, ecstatic,
# Nearest to states: nations, kingdom, us, ateneo, categories, ensemble, liberation, countries,
# Nearest to called: named, used, referred, considered, austerlitz, menstruation, known, supercomputing,
# Average loss at step 92000: 3.396322
# Average loss at step 94000: 3.252954
# Average loss at step 96000: 3.355210
# Average loss at step 98000: 3.244875
# Average loss at step 100000: 3.352788
# Nearest to were: are, have, was, these, had, those, consequently, include,
# Nearest to however: but, although, though, that, while, and, which, where,
# Nearest to who: he, she, never, still, initially, dirichlet, leland, usually,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to and: but, or, like, however, when, impediments, nor, although,
# Nearest to about: over, around, iaea, wreath, weinstein, anode, peculiar, postpone,
# Nearest to this: it, which, some, the, revitalized, he, itself, another,
# Nearest to world: country, galvanized, koenig, kgf, deployable, fastest, catastrophe, essences,
# Nearest to other: various, western, different, handloading, principal, mainstream, mediated, older,
# Nearest to all: any, various, several, every, many, these, some, both,
# Nearest to during: after, in, throughout, before, despite, until, through, when,
# Nearest to had: has, have, was, having, were, malevich, would, began,
# Nearest to as: cometary, bioleaching, beasts, bunker, coincide, arrayed, requiring, daniels,
# Nearest to up: out, off, them, him, back, down, together, ecstatic,
# Nearest to states: nations, kingdom, us, ateneo, state, ohrid, papyri, mueller,
# Nearest to called: named, referred, used, austerlitz, superhuman, known, considered, virginity,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch_cbow(data, skip_window):
  data_index = 0
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  batch = np.ndarray(shape=(len(data)-span+1, 2*skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(len(data)-span+1, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = data_index + 1
  for i in range(batch.shape[0]):
    context = np.ndarray(shape=(2*skip_window), dtype=np.int32)
    count = 0
    for j in range(span):
      if not j==skip_window:
        context[count]=buffer[j]
        count=count +1
    batch[i,:] = context
    labels[i, 0] = buffer[skip_window]
    if data_index < len(data):
      buffer.append(data[data_index])
      data_index = data_index+1
  return batch, labels

def moveBuffer(buf, moveNum, data, data_index):
  for _ in range(moveNum):
    buf.append(data[data_index])
    data_index = (data_index+1)%len(data)
  return data_index

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [3]:
    data_index = 0
    batch, labels = generate_batch_cbow(data[:8], skip_window=skip_window)
    print('\nskip_window = %d:' % skip_window)
    
    print('    batch:', [[reverse_dictionary[bi] for bi in context] for context in batch])
    #for i in range(8):
    #    for j in range(2*skip_window):
    #        print(reverse_dictionary[batch[i,j]])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(batch.shape[0])])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# skip_window = 3:
#     batch: [['anarchism', 'originated', 'as', 'term', 'of', 'abuse'], ['originated', 'as', 'a', 'of', 'abuse', 'first']]
#     labels: ['a', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
  for i in range(2*skip_window-1):
    embed = embed + tf.nn.embedding_lookup(embeddings, train_dataset[:,i+1])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
data_index = 0
buff = collections.deque(maxlen = batch_size +2*skip_window)
data_index = moveBuffer(buff, batch_size+2*skip_window, data, data_index)

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(buff, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    data_index = moveBuffer(buff, batch_size, data, data_index)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.130567
# Nearest to three: nevsky, porter, risky, taraki, viz, resin, corsair, indirect,
# Nearest to no: gravitationally, modifications, juvenile, init, cunt, adequate, rows, voortrekkers,
# Nearest to one: cambodians, bahn, convicts, howe, interferes, westphalian, rob, ige,
# Nearest to up: ferment, minos, superfluous, pentagon, sacramental, powered, epileptic, exeter,
# Nearest to not: jousting, privatized, geopolitical, paterson, turtledove, thr, carnap, peres,
# Nearest to by: episkopos, portrayed, entertainments, redirects, amateurs, acme, plasma, exceeds,
# Nearest to called: immorality, uzbek, cunt, armaments, endoplasmic, anticonvulsant, sepsis, mdf,
# Nearest to he: equalization, faraway, agis, toga, victors, lipschitz, heroics, maloney,
# Nearest to however: shao, lui, dawkins, exmouth, derived, presse, nevertheless, lengthening,
# Nearest to as: paraguayan, masked, note, vero, proteases, anguish, nikolaevich, irritated,
# Nearest to at: vaccinium, unattested, ecoregion, astrology, genesee, counterbalanced, plumes, showered,
# Nearest to world: discriminated, suction, buff, diligently, queene, myrdal, bumps, tournament,
# Nearest to while: predating, thundering, withholding, disregarded, mechanically, siblings, diversifying, eeeeee,
# Nearest to new: take, overtook, reins, glam, signatures, lytton, cookbook, maths,
# Nearest to american: cachet, helmut, fog, sardinia, feasts, caenorhabditis, bains, yesterday,
# Nearest to seven: cushing, redesigned, riddles, brisk, lotharingia, orderly, commandments, idm,
# Average loss at step 2000: 7.671505
# Average loss at step 4000: 5.779065
# Average loss at step 6000: 4.252870
# Average loss at step 8000: 4.144788
# Average loss at step 10000: 5.049806
# Nearest to three: seven, five, two, four, zero, six, deals, barron,
# Nearest to no: rows, governed, jafar, any, motile, another, glitter, that,
# Nearest to one: stature, phrased, echols, prostate, two, iwo, muses, chou,
# Nearest to up: allow, ducas, pike, add, obscurity, buddhas, shameless, place,
# Nearest to not: dunne, pompeii, cassatt, mundane, electronics, snp, lama, erinyes,
# Nearest to by: gibbs, with, wretched, parliamentarians, mesogens, nontrinitarian, vibrio, isolationism,
# Nearest to called: radially, rainer, uzbek, uno, carson, ibiza, known, pwnage,
# Nearest to he: she, it, who, they, toronto, ancillary, tabulate, embassies,
# Nearest to however: and, shao, while, makes, coincide, manson, parapsychology, kapitan,
# Nearest to as: dazzle, inferential, franconia, koran, ebu, cimeti, kegan, carbide,
# Nearest to at: gardening, since, pranksters, over, categorizing, during, riddler, ferromagnetism,
# Nearest to world: badly, borrows, tribesmen, medians, moralistic, imitation, stipulated, recurrent,
# Nearest to while: however, honored, eeeeee, plotters, and, ai, pinball, megalithic,
# Nearest to new: somalia, hein, pregnancy, jerusalem, cleaners, irons, fairs, germanic,
# Nearest to american: cannon, independent, extensionality, nf, trek, alabama, portuguese, cin,
# Nearest to seven: six, three, four, nine, five, zero, interoperable, honorable,
# Average loss at step 12000: 6.163244
# Average loss at step 14000: 3.737338
# Average loss at step 16000: 3.744050
# Average loss at step 18000: 3.620752
# Average loss at step 20000: 3.384357
# Nearest to three: four, seven, six, five, zero, eight, trakai, spore,
# Nearest to no: discrepancy, any, governed, little, charm, cobra, synapomorphies, experiencing,
# Nearest to one: two, supper, feodor, vip, chemists, six, ruins, buffett,
# Nearest to up: him, colors, versus, british, full, kx, staying, unofficial,
# Nearest to not: fits, never, hippocratic, rabies, ulam, gory, so, prions,
# Nearest to by: unconscious, huntingford, luftwaffe, shou, bally, under, eisenman, cbe,
# Nearest to called: named, used, ibiza, radially, but, eugen, like, decayed,
# Nearest to he: she, it, they, eurocents, who, soprano, probes, centimes,
# Nearest to however: while, manson, but, although, girlfriend, optimism, missions, isao,
# Nearest to as: dt, garage, petrie, azov, alces, vocational, venezuelan, decomposing,
# Nearest to at: since, during, directory, simulated, comiskey, exhausts, autistics, dawson,
# Nearest to world: tribesmen, conservatively, culturally, borrows, sheol, immediate, second, niro,
# Nearest to while: however, skeptic, when, and, but, though, hebrew, or,
# Nearest to new: overtook, inasmuch, hymn, milligan, og, categorically, occupying, micromachining,
# Nearest to american: america, international, chirality, vukovar, laity, gage, extensionality, statistically,
# Nearest to seven: six, four, three, eight, five, collective, projectors, pokes,
# Average loss at step 22000: 3.459953
# Average loss at step 24000: 3.444195
# Average loss at step 26000: 3.336613
# Average loss at step 28000: 3.423750
# Average loss at step 30000: 3.313285
# Nearest to three: four, six, two, five, seven, zero, washtenaw, eight,
# Nearest to no: any, a, mnd, wash, cg, discrepancy, unverifiable, bazille,
# Nearest to one: schumpeter, monday, csp, gesellschaft, bins, crewed, informed, bodyline,
# Nearest to up: them, off, down, buddhas, grass, sur, tenants, tirthankaras,
# Nearest to not: now, never, exarch, prions, hippocratic, rabies, mundane, zak,
# Nearest to by: parliamentarians, isolationism, unconscious, limbo, under, chukchi, fairy, anisotropies,
# Nearest to called: used, named, sacrificing, considered, known, anticipate, established, waterfowl,
# Nearest to he: she, it, they, never, nutcracker, centimes, ppm, ancillary,
# Nearest to however: although, though, but, if, since, while, during, that,
# Nearest to as: dt, azov, inferential, vocational, ousting, became, caretaker, nez,
# Nearest to at: directory, since, nicobar, caryophyllales, defer, comiskey, gardening, streetcar,
# Nearest to world: cyber, country, midline, debate, declaring, patriarch, electron, cistern,
# Nearest to while: when, where, though, and, although, however, because, nsted,
# Nearest to new: overtook, inasmuch, hymn, occupying, og, boethius, postulates, neoconservative,
# Nearest to american: america, geniuses, prudence, laity, americans, hangul, apostasy, eskimos,
# Nearest to seven: eight, six, four, three, stockport, five, cavan, popper,
# Average loss at step 32000: 3.536794
# Average loss at step 34000: 3.122683
# Average loss at step 36000: 3.259011
# Average loss at step 38000: 3.255351
# Average loss at step 40000: 3.218215
# Nearest to three: seven, six, two, four, five, eight, palatalized, zero,
# Nearest to no: any, always, little, bodhidharma, an, mnd, nothing, unverifiable,
# Nearest to one: protease, prostate, grasses, goryeo, buffett, electrostatic, remediation, precedence,
# Nearest to up: down, them, out, off, buddhas, veeck, obtain, cabinets,
# Nearest to not: assure, ulam, mundane, indeed, adin, patriot, still, convexity,
# Nearest to by: using, with, when, isolationism, unconscious, on, fairy, regarding,
# Nearest to called: named, considered, used, known, given, described, there, see,
# Nearest to he: she, they, it, nutcracker, eventually, who, cyclonic, dwt,
# Nearest to however: although, but, though, if, that, while, since, where,
# Nearest to as: dt, occidentalis, tammy, garage, inferential, taunted, taney, screenshot,
# Nearest to at: winner, autistics, over, from, pranksters, gardening, through, around,
# Nearest to world: concealment, motto, atlantic, backstage, abbreviations, country, bnf, afforded,
# Nearest to while: and, although, but, where, including, among, however, when,
# Nearest to new: overtook, occupying, corroborate, inasmuch, diffusion, categorically, androgen, prisoner,
# Nearest to american: america, british, flora, respectively, prudence, apostasy, americans, cidre,
# Nearest to seven: six, eight, three, five, four, nine, zero, motte,
# Average loss at step 42000: 3.255159
# Average loss at step 44000: 3.245905
# Average loss at step 46000: 3.194380
# Average loss at step 48000: 3.216752
# Average loss at step 50000: 3.097038
# Nearest to three: five, four, seven, eight, six, zero, two, nine,
# Nearest to no: any, little, nothing, only, always, nai, distaste, reiterated,
# Nearest to one: precedence, gesellschaft, bl, alerted, fasttrack, grams, adc, chlorophyll,
# Nearest to up: off, nc, rivalry, kx, network, out, consular, repeats,
# Nearest to not: never, now, still, nothing, also, rarely, ulam, fux,
# Nearest to by: chukchi, when, isolationism, through, without, parliamentarians, unconscious, huntingford,
# Nearest to called: named, considered, known, installed, described, hadley, used, sacrificing,
# Nearest to he: she, they, it, ruth, ultimately, precursor, ipa, hahn,
# Nearest to however: although, but, while, though, that, where, if, latgale,
# Nearest to as: inextricably, inferential, alces, ebu, dt, decomposing, smyrna, isi,
# Nearest to at: near, in, winner, directory, when, from, during, nicobar,
# Nearest to world: bnf, duets, immediate, culturally, atlantic, tribesmen, u, trickle,
# Nearest to while: when, however, where, although, and, though, nevertheless, before,
# Nearest to new: overtook, small, blender, dusseldorf, large, occupying, hirohito, hymn,
# Nearest to american: british, canadian, prudence, flora, americans, generalised, sixes, america,
# Nearest to seven: eight, six, five, nine, three, four, fenced, fl,
# Average loss at step 52000: 3.086609
# Average loss at step 54000: 3.116639
# Average loss at step 56000: 3.107236
# Average loss at step 58000: 2.940382
# Average loss at step 60000: 3.038712
# Nearest to three: four, five, six, seven, two, eight, zulus, zero,
# Nearest to no: any, another, little, nothing, only, still, cg, sgh,
# Nearest to one: downtown, nz, angevin, captives, aemilius, criticising, carvings, precedence,
# Nearest to up: off, out, down, closer, classifies, zamenhof, them, together,
# Nearest to not: never, still, ulam, nothing, rarely, actually, indeed, without,
# Nearest to by: chukchi, isolationism, unconscious, huntingford, through, facet, sanitary, thus,
# Nearest to called: considered, used, named, applied, added, termed, hadley, created,
# Nearest to he: she, it, nutcracker, they, eventually, accretion, who, ancillary,
# Nearest to however: although, since, but, that, though, structurally, whereby, and,
# Nearest to as: dt, ebu, decomposing, tanaka, azov, tambo, garage, dazzle,
# Nearest to at: autistics, during, near, before, on, nicobar, when, around,
# Nearest to world: europe, winfrey, u, immediate, bnf, couplets, culturally, development,
# Nearest to while: and, though, although, where, but, nevertheless, when, among,
# Nearest to new: overtook, small, occupying, different, categorically, large, hirohito, hymn,
# Nearest to american: america, canadian, english, prudence, australian, independent, british, apostasy,
# Nearest to seven: six, five, eight, four, nine, three, zero, trimming,
# Average loss at step 62000: 3.102522
# Average loss at step 64000: 3.061118
# Average loss at step 66000: 2.916352
# Average loss at step 68000: 2.963190
# Average loss at step 70000: 3.021052
# Nearest to three: seven, five, four, six, two, eight, fifty, coyne,
# Nearest to no: any, nothing, little, another, a, only, neuch, felsic,
# Nearest to one: angevin, gesellschaft, rob, weezer, ploy, empowerment, inconsistently, goryeo,
# Nearest to up: together, off, closer, down, out, rear, zamenhof, wish,
# Nearest to not: never, nothing, still, now, already, without, ulam, almost,
# Nearest to by: chukchi, when, limbo, isolationism, whist, huntingford, regarding, unconscious,
# Nearest to called: considered, named, added, used, known, constructed, applied, placed,
# Nearest to he: she, it, they, who, eventually, we, cyclonic, predators,
# Nearest to however: although, though, but, while, despite, since, times, lonnie,
# Nearest to as: vocational, inextricably, turbine, azov, garage, augusti, decomposing, mortgage,
# Nearest to at: during, near, around, gardening, directory, winner, when, nicobar,
# Nearest to world: trojan, crusade, afforded, effort, country, concealment, ztas, second,
# Nearest to while: although, though, however, and, but, when, behind, provoke,
# Nearest to new: overtook, small, different, massive, occupying, hymn, large, discounts,
# Nearest to american: british, australian, canadian, french, german, ineligible, indian, chosenness,
# Nearest to seven: six, eight, three, five, four, nine, zero, two,
# Average loss at step 72000: 3.091425
# Average loss at step 74000: 3.040360
# Average loss at step 76000: 2.865218
# Average loss at step 78000: 2.998951
# Average loss at step 80000: 3.019865
# Nearest to three: six, four, five, seven, eight, two, nine, zero,
# Nearest to no: nothing, any, another, little, a, only, felsic, every,
# Nearest to one: gesellschaft, offended, nz, monday, feodor, syringe, holbach, empowerment,
# Nearest to up: off, out, closer, them, down, referendums, together, sur,
# Nearest to not: nothing, never, indeed, almost, either, without, still, now,
# Nearest to by: when, chukchi, isolationism, ritz, who, through, transclusion, headset,
# Nearest to called: named, used, known, considered, added, located, placed, defined,
# Nearest to he: she, it, they, who, nutcracker, beaux, slum, modernizing,
# Nearest to however: although, but, though, while, because, and, since, where,
# Nearest to as: ebu, tanaka, tammy, vocational, dazzle, sequels, like, dt,
# Nearest to at: near, during, in, nobi, around, shadowrun, referencing, directory,
# Nearest to world: crusade, effort, trojan, city, flax, backstage, development, happen,
# Nearest to while: although, though, when, however, using, versus, gibbs, neologism,
# Nearest to new: overtook, occupying, large, certain, different, small, specific, hirohito,
# Nearest to american: canadian, australian, america, british, indian, amateur, vukovar, americans,
# Nearest to seven: eight, six, three, four, five, nine, zero, payne,
# Average loss at step 82000: 2.964034
# Average loss at step 84000: 2.876646
# Average loss at step 86000: 2.991520
# Average loss at step 88000: 2.942380
# Average loss at step 90000: 2.952544
# Nearest to three: four, six, five, seven, two, octaves, qf, kx,
# Nearest to no: another, nothing, any, little, kontor, bazille, felsic, francia,
# Nearest to one: ploy, gesellschaft, buffett, ytterbium, discos, vaishnavism, rey, hinckley,
# Nearest to up: out, off, down, together, back, deciduous, wish, forth,
# Nearest to not: never, actually, nothing, still, ulam, rarely, now, already,
# Nearest to by: isolationism, through, without, chukchi, when, mesogens, who, huntingford,
# Nearest to called: named, used, considered, included, added, formed, known, performed,
# Nearest to he: she, it, they, who, there, initially, dwt, icing,
# Nearest to however: although, but, though, if, until, since, while, nevertheless,
# Nearest to as: joyous, azov, tender, dazzle, cowdery, decomposing, ebu, whore,
# Nearest to at: near, during, around, since, when, before, winner, nobi,
# Nearest to world: crusade, country, nation, effort, grasso, debate, europe, decade,
# Nearest to while: although, when, though, where, before, and, among, if,
# Nearest to new: overtook, massive, categorically, emulate, jotham, specific, dusseldorf, predominated,
# Nearest to american: australian, canadian, america, british, french, international, amateur, italian,
# Nearest to seven: eight, six, four, five, nine, three, zero, abjuration,
# Average loss at step 92000: 2.933931
# Average loss at step 94000: 2.843475
# Average loss at step 96000: 2.928686
# Average loss at step 98000: 2.877427
# Average loss at step 100000: 2.659923
# Nearest to three: four, five, six, seven, two, eight, zero, mixolydian,
# Nearest to no: little, nothing, any, bazille, josef, shielded, felsic, chris,
# Nearest to one: gesellschaft, flagging, grasses, copernican, slovakian, vaishnavism, turtledove, empowerment,
# Nearest to up: off, out, together, down, back, closer, forth, referendums,
# Nearest to not: never, nothing, rarely, indeed, almost, ulam, still, unable,
# Nearest to by: isolationism, who, berliners, through, when, chukchi, actually, cto,
# Nearest to called: named, known, considered, used, described, termed, see, referred,
# Nearest to he: she, it, they, there, who, adams, nutcracker, initially,
# Nearest to however: although, though, because, but, while, if, where, since,
# Nearest to as: sequels, whore, organelles, dazzle, azov, contras, foals, hoppers,
# Nearest to at: near, during, around, in, directory, comiskey, autistics, aka,
# Nearest to world: crusade, backstage, wikitravel, grasso, effort, trojan, coasts, era,
# Nearest to while: when, though, although, where, however, nevertheless, before, and,
# Nearest to new: overtook, massive, occupying, categorically, centrifugal, suggestibility, au, pk,
# Nearest to american: canadian, australian, english, british, cimmerians, hillel, america, hawks,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
buffer = collections.deque(maxlen = 10)
window = 2
x = range(20)
index = 0
index = moveBuffer(buffer, 10, x, index)

batch, labels = generate_batch_cbow(buffer, 2)
print(batch)
index = moveBuffer(buffer, 6, x, index)
batch, labels = generate_batch_cbow(buffer, 2)
print(batch)
# Out:
# [[0 1 3 4]
#  [1 2 4 5]
#  [2 3 5 6]
#  [3 4 6 7]
#  [4 5 7 8]
#  [5 6 8 9]]
# [[ 6  7  9 10]
#  [ 7  8 10 11]
#  [ 8  9 11 12]
#  [ 9 10 12 13]
#  [10 11 13 14]
#  [11 12 14 15]]
