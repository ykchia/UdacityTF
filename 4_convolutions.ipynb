# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.777323
# Minibatch accuracy: 18.8%
# Validation accuracy: 11.1%
# Minibatch loss at step 50: 1.430789
# Minibatch accuracy: 43.8%
# Validation accuracy: 61.3%
# Minibatch loss at step 100: 1.078670
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.5%
# Minibatch loss at step 150: 0.294682
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 200: 0.736642
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 250: 1.293562
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.4%
# Minibatch loss at step 300: 0.342571
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.428158
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 400: 0.302040
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.725620
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 500: 0.753031
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 550: 0.877365
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 600: 0.330797
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 650: 0.901308
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 700: 0.820158
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.049447
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 800: 0.620446
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.825725
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 900: 0.495326
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.740403
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.400334
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Test accuracy: 88.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 2 * image_size // 2 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    #hidden = tf.nn.relu(conv + layer1_biases)
    hidden = conv
    conv = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')
    #hidden = tf.nn.relu(conv + layer2_biases)
    hidden = conv
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.428610
# Minibatch accuracy: 0.0%
# Validation accuracy: 12.5%
# Minibatch loss at step 50: 1.029826
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 100: 0.826169
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 150: 0.187352
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 200: 1.062095
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 250: 1.208393
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 300: 0.367465
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 350: 0.523156
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 400: 0.241400
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 450: 0.931319
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 500: 0.639254
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 1.214499
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.341824
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.939772
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 700: 0.827236
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 750: 0.081249
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 800: 0.614542
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.893517
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 900: 0.521433
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 950: 0.601138
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1000: 0.345400
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Test accuracy: 89.1%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth_l0 = num_channels
depth_l1 = 40
depth_l2 = 70
num_hidden = 128
num_hidden2 = 64

graph = tf.Graph()

with graph.as_default():
    
  # helper function for one layer
  def layer(tensor_in, weights, bias, conv_stride, pool_win,pool_stride):
    conv = tf.nn.conv2d(tensor_in, weights, [1, conv_stride, conv_stride, 1], padding='SAME')
    hidden = tf.nn.relu(conv + bias)
    return tf.nn.max_pool(hidden, ksize=[1, pool_win, pool_win, 1],
                        strides=[1, pool_stride, pool_stride, 1], padding='SAME')
  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  keep_prob = tf.placeholder("float")
  layer0_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth_l0], stddev=0.1))
  layer0_biases = tf.Variable(tf.zeros([depth_l0]))

  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth_l0, depth_l1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth_l1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth_l1, depth_l2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_l2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 *depth_l2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  relu2_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden2], stddev=0.1))
  relu2_biases = tf.Variable(tf.constant(1.0, shape = [num_hidden2]))  
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    #conv = layer(data, layer0_weights, layer0_biases, 1, 1, 1)
    conv = layer(data, layer1_weights, layer1_biases, 1, 2, 2)
    conv = layer(conv, layer2_weights, layer2_biases, 1, 2, 2)
    shape = conv.get_shape().as_list()
    reshape = tf.reshape(conv, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.matmul(reshape, layer3_weights) + layer3_biases
    hidden = tf.nn.relu(hidden)
    hidden = tf.nn.dropout(hidden, keep_prob)
    hidden = tf.nn.relu(tf.matmul(hidden, relu2_weights) + relu2_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases

  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    0.1, global_step, 5000, 0.95, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step = global_step)
  #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 45001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob: 0.5}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval({keep_prob:1.0}), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval({keep_prob:1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.464273
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.286115
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.4%
# Minibatch loss at step 100: 2.290174
# Minibatch accuracy: 18.8%
# Validation accuracy: 16.4%
# Minibatch loss at step 150: 1.436430
# Minibatch accuracy: 37.5%
# Validation accuracy: 44.6%
# Minibatch loss at step 200: 1.976190
# Minibatch accuracy: 37.5%
# Validation accuracy: 55.2%
# Minibatch loss at step 250: 1.284918
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.5%
# Minibatch loss at step 300: 1.074805
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.0%
# Minibatch loss at step 350: 0.719387
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.4%
# Minibatch loss at step 400: 0.435233
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 450: 0.824557
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 500: 0.828591
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 550: 1.165347
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.582885
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 650: 1.226986
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 700: 0.877162
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 750: 0.171962
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 800: 0.768574
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 1.036162
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 900: 0.703213
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 950: 0.653140
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 1000: 0.655668
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 1050: 0.878408
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 1100: 0.744487
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 1150: 0.328010
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1200: 0.946379
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 1250: 0.855202
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 1300: 0.633985
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 1350: 0.998150
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1400: 0.461716
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1450: 0.438966
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1500: 0.642169
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 1550: 0.745597
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 1600: 0.933220
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 1650: 0.971574
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 1700: 0.439225
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1750: 0.970415
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 1800: 0.471711
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1850: 0.935796
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1900: 0.556013
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 1950: 0.607039
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2000: 0.111305
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 2050: 0.831985
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 2100: 0.411431
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 2150: 0.717881
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 2200: 0.634842
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 2250: 0.384994
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 2300: 1.110447
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 2350: 0.436120
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 2400: 0.763843
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 2450: 0.815417
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2500: 0.893037
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 2550: 0.672044
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 2600: 0.417752
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 2650: 0.399113
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 2700: 0.669139
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 2750: 1.564668
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2800: 0.648835
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 2850: 0.105466
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2900: 0.432731
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 2950: 0.410535
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 3000: 0.904522
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3050: 0.570398
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 3100: 0.771363
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3150: 0.515446
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 3200: 0.624792
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3250: 0.295612
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 3300: 0.071766
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 3350: 0.250363
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 3400: 0.567924
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 3450: 0.298105
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 3500: 0.801619
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3550: 0.252088
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 3600: 0.223411
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3650: 1.132541
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3700: 1.118781
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 3750: 0.801142
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 3800: 0.010398
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 3850: 0.677828
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 3900: 0.731339
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 3950: 0.013913
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 4000: 0.436055
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 4050: 1.039326
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 4100: 0.553510
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4150: 1.152875
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4200: 0.308302
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4250: 0.470160
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 4300: 0.639134
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 4350: 0.298954
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 4400: 1.196374
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4450: 0.324805
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4500: 0.514997
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 4550: 0.288006
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4600: 0.726386
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4650: 0.890652
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 4700: 0.472749
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4750: 1.227700
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 4800: 0.617959
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 4850: 0.404687
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 4900: 0.167289
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 4950: 0.341140
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 5000: 0.981045
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 5050: 0.275399
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 5100: 0.467678
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 5150: 0.491563
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 5200: 0.330633
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 5250: 0.092920
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 5300: 0.326443
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 5350: 0.302937
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 5400: 0.512396
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 5450: 0.272385
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 5500: 0.607586
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 5550: 0.377757
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 5600: 0.359989
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 5650: 0.345229
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 5700: 0.404146
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 5750: 0.443346
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 5800: 0.355591
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 5850: 0.661265
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 5900: 0.918785
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 5950: 0.580314
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 6000: 0.205427
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 6050: 0.642377
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6100: 0.665938
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 6150: 0.146767
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 6200: 1.182042
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 6250: 0.796431
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 6300: 0.711186
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 6350: 0.334125
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 6400: 0.163243
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 6450: 0.351372
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 6500: 0.711236
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 6550: 0.208171
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 6600: 0.387616
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 6650: 1.640334
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 6700: 0.166590
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 6750: 0.796413
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 6800: 0.809642
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 6850: 0.523772
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 6900: 0.393547
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 6950: 0.407989
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 7000: 0.844450
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 7050: 1.287590
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 7100: 0.851367
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 7150: 0.238598
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 7200: 0.602552
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 7250: 0.449617
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 7300: 0.662073
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 7350: 0.333422
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 7400: 0.074645
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 7450: 0.557160
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 7500: 0.261775
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 7550: 0.285594
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 7600: 0.574120
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 7650: 0.238447
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 7700: 0.284387
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 7750: 0.484574
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 7800: 0.202679
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 7850: 0.872771
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 7900: 0.131913
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 7950: 0.843102
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 8000: 0.402744
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 8050: 0.260878
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 8100: 0.457186
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8150: 0.547042
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 8200: 0.326534
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 8250: 0.213884
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 8300: 0.578130
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 8350: 0.590625
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 8400: 0.260888
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 8450: 0.223962
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 8500: 0.325644
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 8550: 0.329722
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 8600: 0.358360
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8650: 0.337398
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 8700: 0.287484
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 8750: 0.120208
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 8800: 0.214315
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8850: 0.240345
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8900: 0.467451
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 8950: 0.551630
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 9000: 0.414103
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9050: 0.430420
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 9100: 0.238690
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9150: 0.678058
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 9200: 0.221979
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 9250: 0.933166
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 9300: 1.113149
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 9350: 0.287181
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 9400: 0.358269
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 9450: 0.589893
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 9500: 0.143249
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 9550: 0.385556
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 9600: 0.456528
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 9650: 0.694932
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 9700: 0.297924
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 9750: 0.436914
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 9800: 0.608061
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 9850: 0.131320
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 9900: 0.687509
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 9950: 0.281067
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 10000: 0.029480
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 10050: 0.048313
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 10100: 0.518681
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 10150: 0.623174
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 10200: 0.250576
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 10250: 0.388421
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 10300: 0.266914
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 10350: 0.542457
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 10400: 0.300492
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 10450: 0.457865
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 10500: 0.406661
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 10550: 0.903792
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 10600: 0.872050
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 10650: 0.552090
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 10700: 0.060745
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 10750: 0.203513
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 10800: 0.355750
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 10850: 0.756994
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 10900: 0.534227
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 10950: 0.459975
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 11000: 0.236054
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 11050: 0.332228
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 11100: 0.128459
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 11150: 0.492218
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 11200: 0.232752
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 11250: 0.856496
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 11300: 0.433673
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 11350: 0.609954
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 11400: 0.273254
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 11450: 0.297893
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 11500: 0.375994
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 11550: 0.406625
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 11600: 0.400533
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 11650: 0.258585
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 11700: 1.200916
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 11750: 0.572470
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 11800: 0.052940
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 11850: 0.574564
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.1%
# Minibatch loss at step